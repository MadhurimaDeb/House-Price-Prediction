# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import load_boston

# %%
Df = load_boston()
print(Df)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
print(Df.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
df = pd.DataFrame(Df.data , columns = Df.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df['PRICE'] = Df.target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# PRICE      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'PRICE'],
#       dtype='object')

# %%
all_columns = df.columns

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Scale the numeric variables
df[all_columns] = scaler.fit_transform(df[all_columns])

# Print the scaled data
print(df[all_columns])
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.040544    0.113636    0.391378    0.069170    0.349167    0.521869
# std      0.096679    0.233225    0.251479    0.253994    0.238431    0.134627
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000851    0.000000    0.173387    0.000000    0.131687    0.445392
# 50%      0.002812    0.000000    0.338343    0.000000    0.314815    0.507281
# 75%      0.041258    0.125000    0.646628    0.000000    0.491770    0.586798
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.676364    0.242381    0.371713    0.422208    0.622929    0.898568
# ...

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df.corr(), cbar = True, square = True , fmt = '.1f' , annot = True , annot_kws = {'size' : 8} , cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
# Perform outlier analysis on numerical variables
for var in all_columns:
    # Calculate z-scores
    z_scores = (df[var] - df[var].mean()) / df[var].std()
    # Identify outliers using a threshold (e.g., z-score > 3 or < -3)
    outliers = df[z_scores.abs() > 3]
    if not outliers.empty:
        print(f'Outliers in {var}:')
        print(outliers)
# Out:
# Outliers in CRIM:
#          CRIM   ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 380  1.000000  0.0  0.646628   0.0  0.588477  0.652807  0.916581  0.026089
# 398  0.430994  0.0  0.646628   0.0  0.633745  0.362522  1.000000  0.032736
# 404  0.466707  0.0  0.646628   0.0  0.633745  0.377467  0.849640  0.043449
# 405  0.763342  0.0  0.646628   0.0  0.633745  0.406591  1.000000  0.026898
# 410  0.574683  0.0  0.646628   0.0  0.436214  0.420770  1.000000  0.025771
# 414  0.514104  0.0  0.646628   0.0  0.633745  0.183560  1.000000  0.048068
# 418  0.826435  0.0  0.646628   0.0  0.604938  0.459092  1.000000  0.061199
# 427  0.423240  0.0  0.646628   0.0  0.604938  0.506036  0.780639  0.066682
#
#      RAD       TAX   PTRATIO         B     LSTAT     PRICE
# 380  1.0  0.914122  0.808511  1.000000  0.427152  0.120000
# 398  1.0  0.914122  0.808511  1.000000  0.796358  0.000000
# 404  1.0  0.914122  0.808511  0.829946  0.707781  0.077778
# ...

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['PRICE'] , axis = 1)
y = df['PRICE']
X.head()
# Out:
#        CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
#
#         RAD       TAX   PTRATIO         B     LSTAT
# 0  0.000000  0.208015  0.287234  1.000000  0.089680
# 1  0.043478  0.104962  0.553191  1.000000  0.204470
# 2  0.043478  0.104962  0.553191  0.989737  0.063466
# 3  0.086957  0.066794  0.648936  0.994276  0.033389
# 4  0.086957  0.066794  0.648936  1.000000  0.099338

# %%
y.head()
# Out:
# 0    0.422222
# 1    0.368889
# 2    0.660000
# 3    0.631111
# 4    0.693333
# Name: PRICE, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 10)

# %%
X_test
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 305  0.000545  0.33  0.063050   0.0  0.179012  0.585361  0.568486  0.203730
# 193  0.000175  0.60  0.090543   0.0  0.032922  0.620617  0.072091  0.462858
# 65   0.000332  0.80  0.106672   0.0  0.026749  0.522897  0.153450  0.498495
# 349  0.000255  0.40  0.028959   0.0  0.090535  0.647250  0.325438  0.696787
# 151  0.016747  0.00  0.700880   0.0  1.000000  0.353133  1.000000  0.042012
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 493  0.001877  0.00  0.338343   0.0  0.411523  0.411190  0.526262  0.113859
# 142  0.037257  0.00  0.700880   1.0  1.000000  0.352941  1.000000  0.017459
# 26   0.007481  0.00  0.281525   0.0  0.314815  0.431500  0.900103  0.323036
# 173  0.000961  0.00  0.131598   0.0  0.257202  0.547040  0.836251  0.137921
# 428  0.082734  0.00  0.646628   0.0  0.604938  0.504311  0.774459  0.073293
#
#           RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

X_train = scalar.fit_transform(X_train)
X_test = scalar.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-0.23129049, -0.48214334,  1.15722245, ..., -1.78565054,
#         -1.31262649, -0.12068074],
#        [-0.38232604, -0.48214334, -0.2326932 , ..., -0.06432123,
#          0.43624006, -0.37121508],
#        [-0.418341  , -0.48214334, -1.23923336, ..., -0.25041088,
#          0.45387482, -0.95814105],
#        ...,
#        [-0.16882547, -0.48214334,  0.94471469, ...,  0.77308222,
#          0.18079703,  0.04821882],
#        [-0.40749396, -0.48214334,  2.02879146, ...,  0.26133567,
#          0.32990981,  0.25512078],
#        [-0.34348321,  0.34940308, -1.08416012, ..., -2.57653157,
#          0.40691838, -0.35854762]])

# %%
X_test
# Out:
# array([[-0.42328927,  1.06953284, -1.22521443, ...,  0.08763031,
#          0.35957806, -0.37846038],
#        [-0.42869054,  2.36270214, -1.10757754, ..., -1.19472927,
#          0.3597116 , -0.92605159],
#        [-0.42639844,  3.32060532, -1.0385639 , ..., -0.96573649,
#          0.40685206, -0.97659848],
#        ...,
#        [-0.32203687, -0.51100741, -0.2903933 , ...,  1.27839278,
#          0.13950024,  0.44713869],
#        [-0.41722023, -0.51100741, -0.93190646, ..., -0.73674371,
#          0.38815612, -0.3630155 ],
#        [ 0.77646113, -0.51100741,  1.27182457, ...,  0.91200433,
#         -3.60168905,  1.38927639]])

# %% [markdown]
# # training model

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.metrics import r2_score 
from sklearn.linear_model import LinearRegression
lr_model=LinearRegression()
lr_model.fit(X_train,y_train)
y_pred=lr_model.predict(X_test)
score1 = r2_score(y_test,y_pred)
print(score1)
# Out:
# 0.5964201073545576

# %%
y_pred=lr_model.predict(X_test)
y_pred.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
RF_Model=RandomForestRegressor(n_estimators=650,random_state=245,min_samples_leaf=.0001)
RF_Model.fit(X_train,y_train)
y_predict=RF_Model.predict(X_test)
score2 = r2_score(y_test,y_predict)
print(score2)
# Out:
# 0.7836102824736182

# %% [markdown]
# ## ExtraTREE Regression

# %%
from sklearn.ensemble import  ExtraTreesRegressor
ET_Model=ExtraTreesRegressor(n_estimators = 120)
ET_Model.fit(X_train,y_train)
y_predict=ET_Model.predict(X_test)
score3 = r2_score(y_test,y_predict)
print(score3)
# Out:
# 0.7939263138569952

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor()
xgb.fit(X_train,y_train)
y_predict=xgb.predict(X_test)
score3 = r2_score(y_test,y_predict)
print(score3)
# Out:
# 0.7936133482062288

# %% [markdown]
# ### From the avobe three scores it is clear that, xgBoost fits best for this model but according to the task I am supposed to use only linear regression for prediction

# %%
from sklearn.model_selection import cross_val_score

mse = cross_val_score(lr_model,X_train,y_train, scoring='neg_mean_squared_error' , cv=5)
mean_mse = np.mean(mse)
print(mean_mse)
# Out:
# -0.010433796247888337

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'alpha':[1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
ridge = Ridge()


ridge_regressor = GridSearchCV(ridge, params , scoring = 'neg_mean_squared_error', cv=5,n_jobs=-1)
ridge.fit(X_train,y_train)
ridge.score(X_train,y_train)
# Out:
# 0.7575454417836025

# %%
ridge_regressor.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
# Out:
# {'alpha': 5}

# %%
print(ridge_regressor.best_score_)
# Out:
# -0.010425176123725611

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
las = Lasso()

las_regressor = GridSearchCV(las, params, scoring = 'neg_mean_squared_error', cv=5)

las_regressor.fit(X_train,y_train)

print(las_regressor.best_params_)
print(las_regressor.best_score_)
# Out:
# {'alpha': 0.0001}
# -0.010430932310195387

# %%
y_pred = las_regressor.predict(X_test)
print(y_pred)
# Out:
# [ 0.55244558  0.56390098  0.54501523  0.34675124  0.26613143  0.18562628
#   0.63550201  0.18124315  0.40359387  0.66428229  0.32857093  0.52366684
#   0.47980779  0.60740452  0.58963432  0.7371176   0.39282465  0.38123596
#   0.4238502   0.30245548  0.56684471  0.23530111  0.41531237  0.4093832
#   0.57039138  0.31538136  0.29162437  0.21154768  0.68737181 -0.16142518
#   0.56954823  0.56010692  0.43489639  0.3874516   0.30484486  0.29180072
#  -0.09744562  0.63319488  0.45295641  0.46653152  0.60602028  0.51408889
#   0.24863956  0.55476959  0.25955412  0.48364496  0.27428488  0.32018156
#   0.69198648  0.22150756  0.3975222   0.28064281  0.40172151  0.60420807
#   0.43958607  0.6190721   0.32228482  0.28591236  0.27323928  0.3746329
#   0.28917515  0.37413233  0.69782649  0.78288929  0.52585418  0.22686251
#   0.38748806 -0.08412328  0.55212904  0.48067637  0.25081485  0.45796975
#   0.28546684  0.39108371  0.40329658  0.09233687  0.69975847  0.02975754
# ...

# %%
r2_score = r2_score(y_test,y_pred)
print(r2_score)
# Out:
# 0.5966244023984915

# %% [markdown]
# #### Visualising the data

# %%
predicted_data = las_regressor.predict(X_train)

# %%
plt.scatter(y_train,predicted_data)
plt.xlabel("Actual price")
plt.ylabel("Predicted price")
plt.title("Actual price vs Predicted Price")
plt.show()
